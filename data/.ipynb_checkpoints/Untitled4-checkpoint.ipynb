# %%
import json
import pandas as pd
import sqlite3
import geopandas as gpd
import fiona
fiona.supported_drivers
# # Load existing data
# with open('Colorado.geojson') as f:
#   data = json.load(f)

# # Add data 
# feature = {}
# feature['type'] = 'Hazards'
# feature['value'] = {'type': 'Point',
#                        'coordinates': [10, 10],
#                        }
# feature['properties'] =  {'prop0': 'value1'}
# data['features'].append(feature)

# # Write JSON file with new data
# with open('test.json', 'w') as f:
#   f.write(json.dumps(data))
# Out:
# {'DXF': 'rw',
#  'CSV': 'raw',
#  'OpenFileGDB': 'r',
#  'ESRIJSON': 'r',
#  'ESRI Shapefile': 'raw',
#  'FlatGeobuf': 'rw',
#  'GeoJSON': 'raw',
#  'GeoJSONSeq': 'rw',
#  'GPKG': 'raw',
#  'GML': 'rw',
#  'OGR_GMT': 'rw',
#  'GPX': 'rw',
#  'Idrisi': 'r',
#  'MapInfo File': 'raw',
#  'DGN': 'raw',
#  'PCIDSK': 'raw',
#  'OGR_PDS': 'r',
#  'S57': 'r',
#  'SQLite': 'raw',
#  'TopoJSON': 'r'}

# %%
df1 = pd.read_csv('hazardsData.csv')
df1['COUNTY'] = df1['COUNTY'].str.upper()
df1.head()
# Out:
#       COUNTY    AVLN_EALT     CWAV_EALT     DRGT_EALT     HAIL_EALT  \
# 0      ADAMS      0.00000   50174.80969  168054.96470  2.202504e+07
# 1    ALAMOSA  24236.13457  101792.71860  320719.69940  4.787252e+04
# 2   ARAPAHOE      0.00000   41504.22343   49527.89050  4.299513e+07
# 3  ARCHULETA  75622.75287       0.00000   25867.21534  1.529848e+03
# 4       BACA      0.00000   47984.86903  748430.30130  5.565467e+04
#
#       ISTM_EALT      LNDS_EALT     LTNG_EALT      RFLD_EALT      SWND_EALT  \
# 0  62844.110550    7166.124138  698658.35420  601698.148800  208382.768500
# 1   1808.508453     106.954502   23811.13910   57435.368750    1716.979322
# 2  84333.608660    7140.504227  294790.06960  507389.294600  345901.187600
# 3   1418.242381  105300.440500   92819.34388   40763.560820    9047.441492
# 4  10575.787720    2440.961506   19662.19192      25.712489  109487.536000
#
#       TRND_EALT      WFIR_EALT     WNTW_EALT
# 0  9.134780e+06   11408.990980   1618.912928
# ...

# %%
df2 = gpd.read_file('Colorado.geojson')
df2.head()
# Out:
#    FID  OBJECTID      COUNTY               FULL       LABEL CNTY_FIPS  \
# 0    0         1     LARIMER     Larimer County     Larimer       069
# 1    1         2  LAS ANIMAS  Las Animas County  Las Animas       071
# 2    2         3     FREMONT     Fremont County     Fremont       043
# 3    3         4    GUNNISON    Gunnison County    Gunnison       051
# 4    4         5     CONEJOS     Conejos County     Conejos       021
#
#    NUM_FIPS   CENT_LAT   CENT_LONG US_FIPS  \
# 0        69  40.666413 -105.461155   08069
# 1        71  37.315851 -104.038716   08071
# 2        43  38.472972 -105.439657   08043
# 3        51  38.666798 -107.031700   08051
# 4        21  37.200696 -106.191629   08021
#
#                                             geometry
# 0  POLYGON ((-105.05673 40.34929, -105.05664 40.3...
# 1  POLYGON ((-104.14319 37.75834, -104.14408 37.7...
# 2  POLYGON ((-105.36890 38.25941, -105.36889 38.2...
# 3  POLYGON ((-106.79970 38.97966, -106.80041 38.9...
# ...

# %%
df3 = df1.merge(df2, on='COUNTY')
df3.head()
# Out:
#       COUNTY    AVLN_EALT     CWAV_EALT     DRGT_EALT     HAIL_EALT  \
# 0      ADAMS      0.00000   50174.80969  168054.96470  2.202504e+07
# 1    ALAMOSA  24236.13457  101792.71860  320719.69940  4.787252e+04
# 2   ARAPAHOE      0.00000   41504.22343   49527.89050  4.299513e+07
# 3  ARCHULETA  75622.75287       0.00000   25867.21534  1.529848e+03
# 4       BACA      0.00000   47984.86903  748430.30130  5.565467e+04
#
#       ISTM_EALT      LNDS_EALT     LTNG_EALT      RFLD_EALT      SWND_EALT  \
# 0  62844.110550    7166.124138  698658.35420  601698.148800  208382.768500
# 1   1808.508453     106.954502   23811.13910   57435.368750    1716.979322
# 2  84333.608660    7140.504227  294790.06960  507389.294600  345901.187600
# 3   1418.242381  105300.440500   92819.34388   40763.560820    9047.441492
# 4  10575.787720    2440.961506   19662.19192      25.712489  109487.536000
#
#    ...  FID  OBJECTID              FULL      LABEL  CNTY_FIPS NUM_FIPS  \
# ...

# %%
df3.to_json()
# df3.to_file("allData.geojson", driver="GeoJSON")
# Out:
# C:\Users\dikoa\miniconda3\envs\csci1200\lib\site-packages\pandas\io\json\_json.py:172: ShapelyDeprecationWarning: The 'array_interface_base' property is deprecated and will be removed in Shapely 2.0.
#   return dumps(
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# ...
